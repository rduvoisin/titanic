# %%
from __future__ import division
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import operator
import matplotlib.cm as cm
import matplotlib.patches as patches
import math

# %%
train  = pd.read_csv('train.csv')
train.head(50)
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train[(train.Sex=='male') & (train.Survived > 0)].head(10)
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 17           18         1       2     Williams, Mr. Charles Eugene  male
# 21           22         1       2            Beesley, Mr. Lawrence  male
# 23           24         1       1     Sloper, Mr. William Thompson  male
# 36           37         1       3                 Mamee, Mr. Hanna  male
# 55           56         1       1                Woolner, Mr. Hugh  male
# 65           66         1       3         Moubarek, Master. Gerios  male
# 74           75         1       3                    Bing, Mr. Lee  male
# 78           79         1       2    Caldwell, Master. Alden Gates  male
# 81           82         1       3      Sheerlinck, Mr. Jan Baptist  male
# 97           98         1       1  Greenfield, Mr. William Bertram  male
#
#       Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 17    NaN      0      0    244373  13.0000      NaN        S
# 21  34.00      0      0    248698  13.0000      D56        S
# 23  28.00      0      0    113788  35.5000       A6        S
# 36    NaN      0      0      2677   7.2292      NaN        C
# 55    NaN      0      0     19947  35.5000      C52        S
# 65    NaN      1      1      2661  15.2458      NaN        C
# 74  32.00      0      0      1601  56.4958      NaN        S
# 78   0.83      0      2    248738  29.0000      NaN        S
# 81  29.00      0      0    345779   9.5000      NaN        S
# 97  23.00      0      1  PC 17759  63.3583  D10 D12        C

# %%
train['Gender']=train.Sex.map({'female' : 0, 'male' : 1})
train.head(10)
survived = train[train.Survived == 1]

# %%
train.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# Gender           0.647587
# dtype: float64

# %%
survived.mean()
# Out:
# PassengerId    444.368421
# Survived         1.000000
# Pclass           1.950292
# Age             28.343690
# SibSp            0.473684
# Parch            0.464912
# Fare            48.395408
# Gender           0.318713
# dtype: float64

# %%
train[train.Pclass == 3].sort_values('Name').head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 4              5         0       3
# 834          835         0       3
# 192          193         1       3
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# 68            69         1       3
# 541          542         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 845                              Abbing, Mr. Anthony    male   42      0
# 746                      Abbott, Mr. Rossmore Edward    male   16      1
# 279                 Abbott, Mrs. Stanton (Rosa Hunt)  female   35      1
# 365                   Adahl, Mr. Mauritz Nils Martin    male   30      0
# 401                                  Adams, Mr. John    male   26      0
# 40    Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female   40      1
# 855                       Aks, Mrs. Sam (Leah Rosen)  female   18      0
# 207                      Albimona, Mr. Nassef Cassem    male   26      0
# 810                           Alexander, Mr. William    male   26      0
# 840                      Alhomaki, Mr. Ilmari Rudolf    male   20      0
# 210                                   Ali, Mr. Ahmed    male   24      0
# 784                                 Ali, Mr. William    male   25      0
# 4                           Allen, Mr. William Henry    male   35      0
# 834                           Allum, Mr. Owen George    male   18      0
# 192  Andersen-Jensen, Miss. Carla Christine Nielsine  female   19      1
# 850          Andersson, Master. Sigvard Harald Elias    male    4      4
# 813               Andersson, Miss. Ebba Iris Alfrida  female    6      4
# 119                Andersson, Miss. Ellis Anna Maria  female    2      4
# 68                   Andersson, Miss. Erna Alexandra  female   17      4
# 541             Andersson, Miss. Ingeborg Constanzia  female    9      4
#
#      Parch              Ticket     Fare Cabin Embarked  Gender
# 845      0           C.A. 5547   7.5500   NaN        S       1
# 746      1           C.A. 2673  20.2500   NaN        S       1
# 279      1           C.A. 2673  20.2500   NaN        S       0
# 365      0              C 7076   7.2500   NaN        S       1
# 401      0              341826   8.0500   NaN        S       1
# 40       0                7546   9.4750   NaN        S       0
# 855      1              392091   9.3500   NaN        S       0
# 207      0                2699  18.7875   NaN        C       1
# 810      0                3474   7.8875   NaN        S       1
# 840      0    SOTON/O2 3101287   7.9250   NaN        S       1
# 210      0  SOTON/O.Q. 3101311   7.0500   NaN        S       1
# 784      0  SOTON/O.Q. 3101312   7.0500   NaN        S       1
# 4        0              373450   8.0500   NaN        S       1
# 834      0                2223   8.3000   NaN        S       1
# 192      0              350046   7.8542   NaN        S       0
# 850      2              347082  31.2750   NaN        S       1
# 813      2              347082  31.2750   NaN        S       0
# 119      2              347082  31.2750   NaN        S       0
# 68       2             3101281   7.9250   NaN        S       0
# 541      2              347082  31.2750   NaN        S       0

# %%
train.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked',
#        u'Gender'],
#       dtype='object')

# %%
train.shape
# Out:
# (891, 13)

# %%
train.Pclass.describe()
train['ses']= train.Pclass
train.ses.describe()
ses_classes = train.sort_values('ses').ses.unique().tolist()
ses_classes, len(ses_classes)
# Out:
# ([1, 2, 3], 3)

# %%
def get_nice_colors(n_colors):
    '''Helper for plotting colors.'''
    return cm.Accent([1 - (i/n_colors) for i in range(n_colors)])

# %%
plt.close('all')
fig, ax = plt.subplots(figsize=(20,10))
t = 'Survival Rates by SES Group, 1918'
doc = 'daily_crime_rate_bycommunity.png'
proxy_patches = []
proxy_labels = []
ses_list = get_nice_colors(len(ses_classes))
plotting_ses = []
ses_dict = {1 : 'Topsy', 2 : 'Middle', 3: 'Bottomsy'}
for com in ses_classes:
    plotting_ses.append(com)
    median = train[train.ses == com].ses.median()
    proxy_labels.insert(0, "{}, {:.2f}".format(ses_dict[com], median))


train[['Survived', 'ses']].plot(ax=ax, kind='area', rot=90, color=ses_list, title=t)
plt.gcf().tight_layout()
plt.legend(proxy_patches, proxy_labels, title= 'Median Daily Rate')
plt.show()
# fig.savefig(doc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1d7f229cf724> in <module>()
#      14
#      15
# ---> 16 train[['Survived', 'ses']].plot(ax=ax, kind='area', rot=90, color=ses_list, title=t)
#      17 plt.gcf().tight_layout()
#      18 plt.legend(proxy_patches, proxy_labels, title= 'Median Daily Rate')
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in generate(self)
#     985         self._compute_plot_data()
#     986         self._setup_subplots()
# --> 987         self._make_plot()
#     988         self._add_table()
#     989         self._make_legend()
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in _make_plot(self)
#    1647         is_errorbar = any(e is not None for e in self.errors.values())
#    1648
# -> 1649         colors = self._get_colors()
#    1650         for i, (label, y) in enumerate(it):
#    1651             ax = self._get_ax(i)
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in _get_colors(self, num_colors, color_kwds)
#    1371         return _get_standard_colors(num_colors=num_colors,
#    1372                                     colormap=self.colormap,
# -> 1373                                     color=self.kwds.get(color_kwds))
#    1374
#    1375     def _parse_errorbars(self, label, err):
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/tools/plotting.pyc in _get_standard_colors(num_colors, colormap, color_type, color)
#     209
#     210         colors += multiple * colors
# --> 211         colors += colors[:mod]
#     212
#     213     return colors
#
# ValueError: operands could not be broadcast together with shapes (3,4) (2,4) (3,4)
